# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()
print(unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
threshold = 100
application_types_to_replace = application_counts[application_counts < threshold].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_gt_1 = classification_counts[classification_counts > 1]

print(classification_counts_gt_1)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
threshold = 300
classifications_to_replace = classification_counts[classification_counts < threshold].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_cols = ['APPLICATION_TYPE', 'INCOME_AMT', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'SPECIAL_CONSIDERATIONS']
application_df_dummies = pd.get_dummies(application_df, columns=categorical_cols, drop_first=True, dtype='int')

# %%
application_df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  CLASSIFICATION_C7000  \
# 0                    0                    0  ...                     0
# 1                    0                    0  ...                     0
# 2                    0                    0  ...                     0
# 3                    0                    0  ...                     0
# 4                    0                    0  ...                     0
#
#    CLASSIFICATION_Other  USE_CASE_Heathcare  USE_CASE_Other  \
# 0                     0                   0               0
# 1                     0                   0               0
# 2                     0                   0               0
# 3                     0                   0               0
# 4                     0                   1               0
#
#    USE_CASE_Preservation  USE_CASE_ProductDev  ORGANIZATION_Co-operative  \
# 0                      0                    1                          0
# 1                      1                    0                          1
# 2                      0                    1                          0
# 3                      1                    0                          0
# 4                      0                    0                          0
#
#    ORGANIZATION_Corporation  ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_Y
# 0                         0                   0                         0
# 1                         0                   0                         0
# 2                         0                   0                         0
# 3                         0                   1                         0
# 4                         0                   1                         0
#
# [5 rows x 39 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_dummies.drop(columns=['IS_SUCCESSFUL'])
y = application_df_dummies['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

# Define the number of input features
number_input_features = X_train.shape[1]  # Number of features in the training data

# Define the number of hidden nodes for each layer
hidden_nodes_layer1 = 8  # Number of nodes in the first hidden layer
hidden_nodes_layer2 = 5  # Number of nodes in the second hidden layer

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu', input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │             312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │              45 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 363 (1.42 KB)
#  Trainable params: 363 (1.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Create a callback to save the model's weights every 5 epochs
checkpoint_callback = ModelCheckpoint(
    filepath='model.weights.h5',  # Filepath to save the model weights
    save_weights_only=True,         # Save only the weights
    save_freq='epoch',            # Save at the end of every epoch
    verbose=1                      # Verbosity mode, 1 = progress messages
)

# Train the model
fit_model = nn.fit(X_train, y_train, epochs=200, shuffle=True, verbose=2, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
#
# Epoch 1: saving model to model.weights.h5
# 858/858 - 3s - 4ms/step - accuracy: 0.4677 - loss: 90063.5938
# Epoch 2/200
#
# Epoch 2: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5250 - loss: 432.7715
# Epoch 3/200
#
# Epoch 3: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.7091
# Epoch 4/200
#
# Epoch 4: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6944
# Epoch 5/200
#
# Epoch 5: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6913
# Epoch 6/200
#
# Epoch 6: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 7/200
#
# Epoch 7: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 8/200
#
# Epoch 8: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 9/200
#
# Epoch 9: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 10/200
#
# Epoch 10: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 11/200
#
# Epoch 11: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 12/200
#
# Epoch 12: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 13/200
#
# Epoch 13: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 14/200
#
# Epoch 14: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 15/200
#
# Epoch 15: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 16/200
#
# Epoch 16: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 17/200
#
# Epoch 17: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 18/200
#
# Epoch 18: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 19/200
#
# Epoch 19: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 20/200
#
# Epoch 20: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 21/200
#
# Epoch 21: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 22/200
#
# Epoch 22: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 23/200
#
# Epoch 23: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 24/200
#
# Epoch 24: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 25/200
#
# Epoch 25: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 26/200
#
# Epoch 26: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 27/200
#
# Epoch 27: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 28/200
#
# Epoch 28: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 29/200
#
# Epoch 29: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 30/200
#
# Epoch 30: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 31/200
#
# Epoch 31: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 32/200
#
# Epoch 32: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 33/200
#
# Epoch 33: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 34/200
#
# Epoch 34: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 35/200
#
# Epoch 35: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 36/200
#
# Epoch 36: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 37/200
#
# Epoch 37: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 38/200
#
# Epoch 38: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 39/200
#
# Epoch 39: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 40/200
#
# Epoch 40: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 41/200
#
# Epoch 41: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 42/200
#
# Epoch 42: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 43/200
#
# Epoch 43: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 44/200
#
# Epoch 44: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 45/200
#
# Epoch 45: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 46/200
#
# Epoch 46: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 47/200
#
# Epoch 47: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 48/200
#
# Epoch 48: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 49/200
#
# Epoch 49: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 50/200
#
# Epoch 50: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 51/200
#
# Epoch 51: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 52/200
#
# Epoch 52: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 53/200
#
# Epoch 53: saving model to model.weights.h5
# 858/858 - 3s - 4ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 54/200
#
# Epoch 54: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 55/200
#
# Epoch 55: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 56/200
#
# Epoch 56: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 57/200
#
# Epoch 57: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 58/200
#
# Epoch 58: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 59/200
#
# Epoch 59: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 60/200
#
# Epoch 60: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 61/200
#
# Epoch 61: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 62/200
#
# Epoch 62: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 63/200
#
# Epoch 63: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 64/200
#
# Epoch 64: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 65/200
#
# Epoch 65: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 66/200
#
# Epoch 66: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 67/200
#
# Epoch 67: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 68/200
#
# Epoch 68: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 69/200
#
# Epoch 69: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 70/200
#
# Epoch 70: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 71/200
#
# Epoch 71: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 72/200
#
# Epoch 72: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 73/200
#
# Epoch 73: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 74/200
#
# Epoch 74: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 75/200
#
# Epoch 75: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 76/200
#
# Epoch 76: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 77/200
#
# Epoch 77: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 78/200
#
# Epoch 78: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 79/200
#
# Epoch 79: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 80/200
#
# Epoch 80: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 81/200
#
# Epoch 81: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 82/200
#
# Epoch 82: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 83/200
#
# Epoch 83: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 84/200
#
# Epoch 84: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 85/200
#
# Epoch 85: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 86/200
#
# Epoch 86: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 87/200
#
# Epoch 87: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 88/200
#
# Epoch 88: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 89/200
#
# Epoch 89: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 90/200
#
# Epoch 90: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 91/200
#
# Epoch 91: saving model to model.weights.h5
# 858/858 - 3s - 4ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 92/200
#
# Epoch 92: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 93/200
#
# Epoch 93: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 94/200
#
# Epoch 94: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 95/200
#
# Epoch 95: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 96/200
#
# Epoch 96: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 97/200
#
# Epoch 97: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 98/200
#
# Epoch 98: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 99/200
#
# Epoch 99: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 100/200
#
# Epoch 100: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 101/200
#
# Epoch 101: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 102/200
#
# Epoch 102: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 103/200
#
# Epoch 103: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 104/200
#
# Epoch 104: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 105/200
#
# Epoch 105: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 106/200
#
# Epoch 106: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 107/200
#
# Epoch 107: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 108/200
#
# Epoch 108: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 109/200
#
# Epoch 109: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 110/200
#
# Epoch 110: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 111/200
#
# Epoch 111: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 112/200
#
# Epoch 112: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 113/200
#
# Epoch 113: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 114/200
#
# Epoch 114: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 115/200
#
# Epoch 115: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 116/200
#
# Epoch 116: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 117/200
#
# Epoch 117: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 118/200
#
# Epoch 118: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 119/200
#
# Epoch 119: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 120/200
#
# Epoch 120: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 121/200
#
# Epoch 121: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 122/200
#
# Epoch 122: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 123/200
#
# Epoch 123: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 124/200
#
# Epoch 124: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 125/200
#
# Epoch 125: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 126/200
#
# Epoch 126: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 127/200
#
# Epoch 127: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 128/200
#
# Epoch 128: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 129/200
#
# Epoch 129: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 130/200
#
# Epoch 130: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 131/200
#
# Epoch 131: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 132/200
#
# Epoch 132: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 133/200
#
# Epoch 133: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 134/200
#
# Epoch 134: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 135/200
#
# Epoch 135: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 136/200
#
# Epoch 136: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 137/200
#
# Epoch 137: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 138/200
#
# Epoch 138: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 139/200
#
# Epoch 139: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 140/200
#
# Epoch 140: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 141/200
#
# Epoch 141: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 142/200
#
# Epoch 142: saving model to model.weights.h5
# 858/858 - 3s - 4ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 143/200
#
# Epoch 143: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 144/200
#
# Epoch 144: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 145/200
#
# Epoch 145: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 146/200
#
# Epoch 146: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 147/200
#
# Epoch 147: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 148/200
#
# Epoch 148: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 149/200
#
# Epoch 149: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 150/200
#
# Epoch 150: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 151/200
#
# Epoch 151: saving model to model.weights.h5
# 858/858 - 3s - 4ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 152/200
#
# Epoch 152: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 153/200
#
# Epoch 153: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 154/200
#
# Epoch 154: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 155/200
#
# Epoch 155: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 156/200
#
# Epoch 156: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 157/200
#
# Epoch 157: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 158/200
#
# Epoch 158: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 159/200
#
# Epoch 159: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 160/200
#
# Epoch 160: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 161/200
#
# Epoch 161: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 162/200
#
# Epoch 162: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 163/200
#
# Epoch 163: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 164/200
#
# Epoch 164: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 165/200
#
# Epoch 165: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 166/200
#
# Epoch 166: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 167/200
#
# Epoch 167: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 168/200
#
# Epoch 168: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 169/200
#
# Epoch 169: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 170/200
#
# Epoch 170: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 171/200
#
# Epoch 171: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 172/200
#
# Epoch 172: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 173/200
#
# Epoch 173: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 174/200
#
# Epoch 174: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 175/200
#
# Epoch 175: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 176/200
#
# Epoch 176: saving model to model.weights.h5
# 858/858 - 3s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 177/200
#
# Epoch 177: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 178/200
#
# Epoch 178: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 179/200
#
# Epoch 179: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 180/200
#
# Epoch 180: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 181/200
#
# Epoch 181: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 182/200
#
# Epoch 182: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 183/200
#
# Epoch 183: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 184/200
#
# Epoch 184: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 185/200
#
# Epoch 185: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 186/200
#
# Epoch 186: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 187/200
#
# Epoch 187: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 188/200
#
# Epoch 188: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 189/200
#
# Epoch 189: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 190/200
#
# Epoch 190: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 191/200
#
# Epoch 191: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 192/200
#
# Epoch 192: saving model to model.weights.h5
# 858/858 - 2s - 3ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 193/200
#
# Epoch 193: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 194/200
#
# Epoch 194: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 195/200
#
# Epoch 195: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6910
# Epoch 196/200
#
# Epoch 196: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 197/200
#
# Epoch 197: saving model to model.weights.h5
# 858/858 - 1s - 2ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 198/200
#
# Epoch 198: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 199/200
#
# Epoch 199: saving model to model.weights.h5
# 858/858 - 1s - 1ms/step - accuracy: 0.5323 - loss: 0.6911
# Epoch 200/200
#
# Epoch 200: saving model to model.weights.h5
# 858/858 - 2s - 2ms/step - accuracy: 0.5323 - loss: 0.6911

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 1s - 3ms/step - accuracy: 0.6367 - loss: 0.6645
# Loss: 0.6644928455352783, Accuracy: 0.636734664440155

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
